# %% [markdown]
# <a href="https://colab.research.google.com/github/ahrbadr/QSAR-Model-for-BACE1/blob/main/BACE1_part6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **QSAR Model Building of BACE1 Inhibitors**

# %% [markdown]
# # Read in data

# %%
import pandas as pd

# %%
dataset = pd.read_csv("BACE1_06_bioactivity_data_3class_pIC50_pubchem_fp.csv")
dataset
# Out:
#       PubchemFP0  PubchemFP1  PubchemFP2  ...  PubchemFP879  PubchemFP880     pIC50
# 0              1           1           1  ...             0             0  6.384050
# 1              1           1           1  ...             0             0  8.698970
# 2              1           1           1  ...             0             0  6.337242
# 3              1           1           1  ...             0             0  5.045757
# 4              1           1           1  ...             0             0  5.251812
# ...          ...         ...         ...  ...           ...           ...       ...
# 7057           1           1           1  ...             0             0  4.480000
# 7058           1           1           1  ...             0             0  4.070000
# 7059           1           1           1  ...             0             0  4.540000
# 7060           1           1           1  ...             0             0  4.260000
# ...

# %%
X = dataset.drop(['pIC50'], axis=1)
X
# Out:
#       PubchemFP0  PubchemFP1  ...  PubchemFP879  PubchemFP880
# 0              1           1  ...             0             0
# 1              1           1  ...             0             0
# 2              1           1  ...             0             0
# 3              1           1  ...             0             0
# 4              1           1  ...             0             0
# ...          ...         ...  ...           ...           ...
# 7057           1           1  ...             0             0
# 7058           1           1  ...             0             0
# 7059           1           1  ...             0             0
# 7060           1           1  ...             0             0
# 7061           1           1  ...             0             0
#
# [7062 rows x 881 columns]

# %%
Y = dataset.iloc[:,-1]
Y
# Out:
# 0       6.384050
# 1       8.698970
# 2       6.337242
# 3       5.045757
# 4       5.251812
#           ...
# 7057    4.480000
# 7058    4.070000
# 7059    4.540000
# 7060    4.260000
# 7061    4.510000
# Name: pIC50, Length: 7062, dtype: float64

# %% [markdown]
# # Remove low variance features

# %%
from sklearn.feature_selection import VarianceThreshold

def remove_low_variance(input_data, threshold=0.1):
    selection = VarianceThreshold(threshold)
    selection.fit(input_data)
    return input_data[input_data.columns[selection.get_support(indices=True)]]

X = remove_low_variance(X, threshold=0.1)
X
# Out:
#       PubchemFP3  PubchemFP13  ...  PubchemFP819  PubchemFP860
# 0              1            1  ...             0             0
# 1              1            1  ...             0             0
# 2              1            1  ...             0             0
# 3              1            1  ...             0             0
# 4              1            1  ...             0             0
# ...          ...          ...  ...           ...           ...
# 7057           0            0  ...             0             0
# 7058           0            0  ...             0             0
# 7059           0            0  ...             0             0
# 7060           0            0  ...             0             0
# 7061           0            0  ...             0             1
#
# [7062 rows x 218 columns]

# %%
X.to_csv('descriptor_list.csv', index = False)

# %%
# In the app, use the following to get this same descriptor list
# of 218 variables from the initial set of 881 variables
Xlist = list(pd.read_csv('descriptor_list.csv').columns)
X[Xlist]
# Out:
#       PubchemFP3  PubchemFP13  ...  PubchemFP819  PubchemFP860
# 0              1            1  ...             0             0
# 1              1            1  ...             0             0
# 2              1            1  ...             0             0
# 3              1            1  ...             0             0
# 4              1            1  ...             0             0
# ...          ...          ...  ...           ...           ...
# 7057           0            0  ...             0             0
# 7058           0            0  ...             0             0
# 7059           0            0  ...             0             0
# 7060           0            0  ...             0             0
# 7061           0            0  ...             0             1
#
# [7062 rows x 218 columns]

# %% [markdown]
# # Random Forest Regression Model

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error, r2_score

# %%
model = RandomForestRegressor(n_estimators=500, random_state=42)
model.fit(X, Y)
r2 = model.score(X, Y)
r2
# Out:
# 0.8721985246851728

# %% [markdown]
# ## Model Prediction

# %%
Y_pred = model.predict(X)
Y_pred
# Out:
# array([6.33325427, 7.42722525, 5.77475309, ..., 4.5823986 , 4.66523814,
#        4.90005904])

# %% [markdown]
# ## Model Performance

# %%
print('Mean squared error (MSE): %.2f'
      % mean_squared_error(Y, Y_pred))
print('Coefficient of determination (R^2): %.2f'
      % r2_score(Y, Y_pred))
# Out:
# Mean squared error (MSE): 0.25
# Coefficient of determination (R^2): 0.87

# %% [markdown]
# # Data Visualization (Experimental vs Predicted pIC50 for Training Data)

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
plt.figure(figsize=(5,5))
plt.scatter(x=Y, y=Y_pred, c="#7CAE00", alpha=0.3)

# Add trendline
# https://stackoverflow.com/questions/26447191/how-to-add-trendline-in-python-matplotlib-dot-scatter-graphs
z = np.polyfit(Y, Y_pred, 1)
p = np.poly1d(z)

plt.plot(Y,p(Y),"#F8766D")
plt.ylabel('Predicted pIC50')
plt.xlabel('Experimental pIC50')
# Out:
# Text(0.5, 0, 'Experimental pIC50')

# %% [markdown]
# # Save Model as Pickle Object

# %%
import pickle

# %%
pickle.dump(model, open('BACE1.pkl', 'wb'))
