# %% [markdown]
# <a href="https://colab.research.google.com/github/ahrbadr/QSAR-Model-for-BACE1/blob/main/BACE1_part4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Computational Drug Discovery [Part 4] Regression Models with Random Forest**

# %% [markdown]
# ## **1. Import libraries**

# %%
import pandas as pd
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor

# %%
df = pd.read_csv('BACE1_06_bioactivity_data_3class_pIC50_pubchem_fp.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-2-f43bc4289d66> in <module>()
# ----> 1 df = pd.read_csv('BACE1_06_bioactivity_data_3class_pIC50_pubchem_fp.csv')
#
# /usr/local/lib/python3.7/dist-packages/pandas/io/parsers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     686     )
#     687
# ...

# %% [markdown]
# ## **2. Input features**
# The ***BACE1*** data set contains 881 input features and 1 output variable (pIC50 values).

# %% [markdown]
# ### **2.1. Input features**

# %%
X = df.drop('pIC50', axis=1)
X
# Out:
#       PubchemFP0  PubchemFP1  ...  PubchemFP879  PubchemFP880
# 0              1           1  ...             0             0
# 1              1           1  ...             0             0
# 2              1           1  ...             0             0
# 3              1           1  ...             0             0
# 4              1           1  ...             0             0
# ...          ...         ...  ...           ...           ...
# 7057           1           1  ...             0             0
# 7058           1           1  ...             0             0
# 7059           1           1  ...             0             0
# 7060           1           1  ...             0             0
# 7061           1           1  ...             0             0
#
# [7062 rows x 881 columns]

# %% [markdown]
# ### **2.2. Output features**

# %%
Y = df.pIC50
Y
# Out:
# 0       6.384050
# 1       8.698970
# 2       6.337242
# 3       5.045757
# 4       5.251812
#           ...
# 7057    4.480000
# 7058    4.070000
# 7059    4.540000
# 7060    4.260000
# 7061    4.510000
# Name: pIC50, Length: 7062, dtype: float64

# %% [markdown]
# ### **2.3. Let's examine the data dimension**

# %%
X.shape
# Out:
# (7062, 881)

# %%
Y.shape
# Out:
# (7062,)

# %% [markdown]
# ### **2.4. Remove low variance features**

# %%
from sklearn.feature_selection import VarianceThreshold
selection = VarianceThreshold(threshold=(.8 * (1 - .8)))    
X = selection.fit_transform(X)

# %%
X.shape
# Out:
# (7062, 160)

# %% [markdown]
# ## **3. Data split (80/20 ratio)**

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2)

# %%
X_train.shape, Y_train.shape
# Out:
# ((5649, 160), (5649,))

# %%
X_test.shape, Y_test.shape
# Out:
# ((1413, 160), (1413,))

# %% [markdown]
# ## **4. Building a Regression Model using Random Forest**

# %%
model = RandomForestRegressor(n_estimators=100)
model.fit(X_train, Y_train)
r2 = model.score(X_test, Y_test)
r2
# Out:
# 0.5178773115578135

# %%
Y_pred = model.predict(X_test)

# %% [markdown]
# ## **5. Scatter Plot of Experimental vs Predicted pIC50 Values**

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.set(color_codes=True)
sns.set_style("white")

ax = sns.regplot(Y_test, Y_pred, scatter_kws={'alpha':0.4})
ax.set_xlabel('Experimental pIC50', fontsize='large', fontweight='bold')
ax.set_ylabel('Predicted pIC50', fontsize='large', fontweight='bold')
ax.set_xlim(0, 12)
ax.set_ylim(0, 12)
ax.figure.set_size_inches(5, 5)
plt.show
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# <function matplotlib.pyplot.show>
